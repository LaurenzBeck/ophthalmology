# %%
import einops
import torch
import pandas as pd
import numpy as np
import altair as alt
from torchvision import transforms
import matplotlib.pyplot as plt
from self_supervised.vision import simclr
from tqdm import tqdm
import torchinfo

from ophthalmology.data.sets import IndianDiabeticRetinopythyDetection
from ophthalmology.models import resnet

# %matplotlib inline

# %%
data = IndianDiabeticRetinopythyDetection( 
    image_dir="../../data/indian-diabetic-retinopythy-image-dataset/B. Disease Grading/1. Original Images/a. Training Set",
    csv_file="../../data/indian-diabetic-retinopythy-image-dataset/B. Disease Grading/2. Groundtruths/a. IDRiD_Disease Grading_Training Labels.csv",
    transform=None
)

# %%
len(data)
# Out:
# 413

# %%
plt.imshow(data[0][0])

# %%
data[0][1]
# Out:
# tensor(3)
